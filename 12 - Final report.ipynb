# %% [markdown]
# # 12 - Final report

# %% [markdown]
# ## Low energy trackster (8 GeV)

# %% [markdown]
# ### for 1 connection per vertex

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12for 1 connection per vertex))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_l, 
    vertices_y_l, 
    vertices_z_l, 
    heatmap=vertices_E_l, 
    indexes=vertices_indexes_l, 
    edges=edges_l_1,
    label='Vertex Energy (GeV)'
)

# %% [markdown]
# ### for 5 connections per vertex

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_l, 
    vertices_y_l, 
    vertices_z_l, 
    heatmap=vertices_E_l, 
    indexes=vertices_indexes_l, 
    edges=edges_l_5,
    label='Vertex Energy (GeV)'
)

# %% [markdown]
# ## high energy trackster (316 GeV)
# ### for 1 connections per vertex

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_h, 
    vertices_y_h, 
    vertices_z_h, 
    heatmap=vertices_E_h, 
    indexes=vertices_indexes_h, 
    edges=edges_h_1,
    label='Vertex Energy (GeV)'
)

# %% [markdown]
# ### for 5 connections per vertex

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_h, 
    vertices_y_h, 
    vertices_z_h, 
    heatmap=vertices_E_h, 
    indexes=vertices_indexes_h, 
    edges=edges_h_5,
    label='Vertex Energy (GeV)'
)

# %% [markdown]
# ## Centrality

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_l, 
    vertices_y_l, 
    vertices_z_l, 
    heatmap=c_eig_l_1, 
    indexes=vertices_indexes_l, 
    edges=edges_l_1,
    label='centrality eigenvector'
)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_l, 
    vertices_y_l, 
    vertices_z_l, 
    heatmap=c_eig_l_5, 
    indexes=vertices_indexes_l, 
    edges=edges_l_5,
    label='centrality eigenvector'
)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_h, 
    vertices_y_h, 
    vertices_z_h, 
    heatmap=c_eig_h_1, 
    indexes=vertices_indexes_h, 
    edges=edges_h_1,
    label='centrality eigenvector'
)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

fn.plotTrackster(
    fig, 
    ax, 
    vertices_x_h, 
    vertices_y_h, 
    vertices_z_h, 
    heatmap=c_eig_h_5, 
    indexes=vertices_indexes_h, 
    edges=edges_h_5,
    label='centrality eigenvector'
)

# %% [markdown]
# ## Incomplete tracksters

# %%
# %matplotlib inline

plotEnergyCentrality(vertices10e_indexes, vertices10e_x, vertices10e_y, vertices10e_z, vertices10e_E,
                     edges10e,358)

# %% [markdown]
# ## Metric: Pick node with max centrality and use the distance of the most distant node

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(longestComPaths, bins=20, color='b', alpha=0.7,label='Complete')
plt.hist(longestInComPaths, bins=10, color='r', alpha=0.7,label='Incomplete')
plt.legend()
plt.ylabel("N")
plt.xlabel("Longest path in the network")
plt.title("200e dataset Eigen centrality")
plt.show()
